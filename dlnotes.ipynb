# %%
import numpy as np

# %%
x=np.array([[0.,1.],
            [2.,3.],
            [4.,5.]])

# %%
x.reshape(2,3)
# Out:
# array([[0., 1., 2.],
#        [3., 4., 5.]])

# %%
pointA=np.array([.5, 1])
pointB=np.array([1, .25])

# %%
pointA+pointB
# Out:
# array([1.5 , 1.25])

# %%
0.3-0.05
# Out:
# 0.25
